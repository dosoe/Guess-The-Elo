# %%
pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.5 MB 2.8 MB/s eta 0:00:04
#    --- ------------------------------------ 1.0/11.5 MB 2.5 MB/s eta 0:00:05
#    ---- ----------------------------------- 1.3/11.5 MB 2.4 MB/s eta 0:00:05
#    ------ --------------------------------- 1.8/11.5 MB 2.3 MB/s eta 0:00:05
#    ------- -------------------------------- 2.1/11.5 MB 2.3 MB/s eta 0:00:05
#    -------- ------------------------------- 2.4/11.5 MB 1.9 MB/s eta 0:00:05
#    ---------- ----------------------------- 2.9/11.5 MB 2.0 MB/s eta 0:00:05
#    ---------- ----------------------------- 3.1/11.5 MB 2.0 MB/s eta 0:00:05
#    ----------- ---------------------------- 3.4/11.5 MB 1.9 MB/s eta 0:00:05
#    ------------ --------------------------- 3.7/11.5 MB 1.8 MB/s eta 0:00:05
#    ------------- -------------------------- 3.9/11.5 MB 1.8 MB/s eta 0:00:05
# ...

# %%
import pandas as pd

# %%
df=pd.read_csv("analysis_results4.csv")

# %%
df.head()
# Out:
#    GameID        Rating  Opening                   Variation  ACPL_White  \
# 0       1  2755 vs 2733  English  Caro-Kann defensive system       16.44
# 1       1           NaN      NaN                         NaN         NaN
# 2       1           NaN      NaN                         NaN         NaN
# 3       1           NaN      NaN                         NaN         NaN
# 4       1           NaN      NaN                         NaN         NaN
#
#    ACPL_Black  MoveNumber Move   CPL
# 0       19.16         1.0   c4  21.0
# 1         NaN         2.0   c6  24.0
# 2         NaN         3.0  Nf3   5.0
# 3         NaN         4.0   d5   1.0
# 4         NaN         5.0   e3   3.0

# %%
metadata_cols = ['Rating', 'Opening', 'Variation', 'ACPL_White', 'ACPL_Black']
df[metadata_cols] = df[metadata_cols].ffill()
df.head()
# Out:
#    GameID        Rating  Opening                   Variation  ACPL_White  \
# 0       1  2755 vs 2733  English  Caro-Kann defensive system       16.44
# 1       1  2755 vs 2733  English  Caro-Kann defensive system       16.44
# 2       1  2755 vs 2733  English  Caro-Kann defensive system       16.44
# 3       1  2755 vs 2733  English  Caro-Kann defensive system       16.44
# 4       1  2755 vs 2733  English  Caro-Kann defensive system       16.44
#
#    ACPL_Black  MoveNumber Move   CPL
# 0       19.16         1.0   c4  21.0
# 1       19.16         2.0   c6  24.0
# 2       19.16         3.0  Nf3   5.0
# 3       19.16         4.0   d5   1.0
# 4       19.16         5.0   e3   3.0
